# %%
import pandas as pd

test_data = pd.read_csv('./data/test.csv')
train_data = pd.read_csv('./data/train.csv')

# %%
test_data.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# 1          7        1             0     0
# 2         10        0             1     1
# 3          7        1             1     0
# 4          7        1             0     1
#
# [5 rows x 21 columns]

# %%
test_data = test_data.drop("id", axis=1)

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  1000 non-null   int64
#  1   blue           1000 non-null   int64
#  2   clock_speed    1000 non-null   float64
#  3   dual_sim       1000 non-null   int64
#  4   fc             1000 non-null   int64
#  5   four_g         1000 non-null   int64
#  6   int_memory     1000 non-null   int64
#  7   m_dep          1000 non-null   float64
#  8   mobile_wt      1000 non-null   int64
#  9   n_cores        1000 non-null   int64
#  10  pc             1000 non-null   int64
#  11  px_height      1000 non-null   int64
#  12  px_width       1000 non-null   int64
#  13  ram            1000 non-null   int64
#  14  sc_h           1000 non-null   int64
#  15  sc_w           1000 non-null   int64
#  16  talk_time      1000 non-null   int64
#  17  three_g        1000 non-null   int64
#  18  touch_screen   1000 non-null   int64
#  19  wifi           1000 non-null   int64
# dtypes: float64(2), int64(18)
# memory usage: 156.4 KB

# %%
train_data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
#  18  touch_screen   2000 non-null   int64
#  19  wifi           2000 non-null   int64
#  20  price_range    2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB

# %%
train_data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
train_data.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# px_width           -0.008402 -0.041533    -0.009476  0.014291 -0.005176
# ram                -0.000653  0.026351     0.003443  0.041072  0.015099
# sc_h               -0.029959 -0.002952    -0.029078 -0.011949 -0.011014
# sc_w               -0.021421  0.000613    -0.007378 -0.016666 -0.012373
# talk_time           0.052510  0.013934    -0.011432 -0.039404 -0.006829
# three_g             0.011522 -0.030236    -0.046433 -0.014008  0.001793
# touch_screen       -0.010516  0.010061     0.019756 -0.017117 -0.014828
# wifi               -0.008343 -0.021863    -0.024471  0.022740  0.020085
# price_range         0.200723  0.020573    -0.006606  0.017444  0.021998
#
#                  four_g  int_memory     m_dep  mobile_wt   n_cores  ...  \
# battery_power  0.015665   -0.004004  0.034085   0.001844 -0.029727  ...
# blue           0.013443    0.041177  0.004049  -0.008605  0.036161  ...
# clock_speed   -0.043073    0.006545 -0.014364   0.012350 -0.005724  ...
# dual_sim       0.003187   -0.015679 -0.022142  -0.008979 -0.024658  ...
# fc            -0.016560   -0.029133 -0.001791   0.023618 -0.013356  ...
# four_g         1.000000    0.008690 -0.001823  -0.016537 -0.029706  ...
# int_memory     0.008690    1.000000  0.006886  -0.034214 -0.028310  ...
# m_dep         -0.001823    0.006886  1.000000   0.021756 -0.003504  ...
# mobile_wt     -0.016537   -0.034214  0.021756   1.000000 -0.018989  ...
# n_cores       -0.029706   -0.028310 -0.003504  -0.018989  1.000000  ...
# pc            -0.005598   -0.033273  0.026282   0.018844 -0.001193  ...
# px_height     -0.019236    0.010441  0.025263   0.000939 -0.006872  ...
# px_width       0.007448   -0.008335  0.023566   0.000090  0.024480  ...
# ram            0.007313    0.032813 -0.009434  -0.002581  0.004868  ...
# sc_h           0.027166    0.037771 -0.025348  -0.033855 -0.000315  ...
# sc_w           0.037005    0.011731 -0.018388  -0.020761  0.025826  ...
# talk_time     -0.046628   -0.002790  0.017003   0.006209  0.013148  ...
# three_g        0.584246   -0.009366 -0.012065   0.001551 -0.014733  ...
# touch_screen   0.016758   -0.026999 -0.002638  -0.014368  0.023774  ...
# wifi          -0.017620    0.006993 -0.028353  -0.000409 -0.009964  ...
# price_range    0.014772    0.044435  0.000853  -0.030302  0.004399  ...
#
#                px_height  px_width       ram      sc_h      sc_w  talk_time  \
# battery_power   0.014901 -0.008402 -0.000653 -0.029959 -0.021421   0.052510
# blue           -0.006872 -0.041533  0.026351 -0.002952  0.000613   0.013934
# clock_speed    -0.014523 -0.009476  0.003443 -0.029078 -0.007378  -0.011432
# dual_sim       -0.020875  0.014291  0.041072 -0.011949 -0.016666  -0.039404
# fc             -0.009990 -0.005176  0.015099 -0.011014 -0.012373  -0.006829
# four_g         -0.019236  0.007448  0.007313  0.027166  0.037005  -0.046628
# int_memory      0.010441 -0.008335  0.032813  0.037771  0.011731  -0.002790
# m_dep           0.025263  0.023566 -0.009434 -0.025348 -0.018388   0.017003
# mobile_wt       0.000939  0.000090 -0.002581 -0.033855 -0.020761   0.006209
# n_cores        -0.006872  0.024480  0.004868 -0.000315  0.025826   0.013148
# pc             -0.018465  0.004196  0.028984  0.004938 -0.023819   0.014657
# px_height       1.000000  0.510664 -0.020352  0.059615  0.043038  -0.010645
# px_width        0.510664  1.000000  0.004105  0.021599  0.034699   0.006720
# ram            -0.020352  0.004105  1.000000  0.015996  0.035576   0.010820
# sc_h            0.059615  0.021599  0.015996  1.000000  0.506144  -0.017335
# sc_w            0.043038  0.034699  0.035576  0.506144  1.000000  -0.022821
# talk_time      -0.010645  0.006720  0.010820 -0.017335 -0.022821   1.000000
# three_g        -0.031174  0.000350  0.015795  0.012033  0.030941  -0.042688
# touch_screen    0.021891 -0.001628 -0.030455 -0.020023  0.012720   0.017196
# wifi            0.051824  0.030319  0.022669  0.025929  0.035423  -0.029504
# price_range     0.148858  0.165818  0.917046  0.022986  0.038711   0.021859
#
#                 three_g  touch_screen      wifi  price_range
# battery_power  0.011522     -0.010516 -0.008343     0.200723
# blue          -0.030236      0.010061 -0.021863     0.020573
# clock_speed   -0.046433      0.019756 -0.024471    -0.006606
# dual_sim      -0.014008     -0.017117  0.022740     0.017444
# fc             0.001793     -0.014828  0.020085     0.021998
# four_g         0.584246      0.016758 -0.017620     0.014772
# int_memory    -0.009366     -0.026999  0.006993     0.044435
# m_dep         -0.012065     -0.002638 -0.028353     0.000853
# mobile_wt      0.001551     -0.014368 -0.000409    -0.030302
# n_cores       -0.014733      0.023774 -0.009964     0.004399
# pc            -0.001322     -0.008742  0.005389     0.033599
# px_height     -0.031174      0.021891  0.051824     0.148858
# px_width       0.000350     -0.001628  0.030319     0.165818
# ram            0.015795     -0.030455  0.022669     0.917046
# sc_h           0.012033     -0.020023  0.025929     0.022986
# sc_w           0.030941      0.012720  0.035423     0.038711
# talk_time     -0.042688      0.017196 -0.029504     0.021859
# three_g        1.000000      0.013917  0.004316     0.023611
# touch_screen   0.013917      1.000000  0.011917    -0.030411
# wifi           0.004316      0.011917  1.000000     0.018785
# price_range    0.023611     -0.030411  0.018785     1.000000
#
# [21 rows x 21 columns]

# %%
# train_data.corr()
import seaborn as sns
import matplotlib.pyplot as plt
corr=train_data.corr()
fig = plt.figure(figsize=(15,12))
r = sns.heatmap(corr, cmap='Purples')
r.set_title("Correlation ")
# Out:
# Text(0.5, 1.0, 'Correlation ')

# %%
fig.savefig('Corr.png')

# %%
corr.sort_values(by=["price_range"],ascending=False).iloc[0].sort_values(ascending=False)
# Out:
# price_range      1.000000
# ram              0.917046
# battery_power    0.200723
# px_width         0.165818
# px_height        0.148858
# int_memory       0.044435
# sc_w             0.038711
# pc               0.033599
# three_g          0.023611
# sc_h             0.022986
# fc               0.021998
# talk_time        0.021859
# blue             0.020573
# wifi             0.018785
# dual_sim         0.017444
# four_g           0.014772
# n_cores          0.004399
# m_dep            0.000853
# clock_speed     -0.006606
# mobile_wt       -0.030302
# touch_screen    -0.030411
# Name: price_range, dtype: float64

# %%
dataframe_lst = corr.sort_values(by=["price_range"],ascending=False).iloc[0].sort_values(ascending=False)

# %%
ram_lst = [[], [], [], []]
battery_lst = [[], [], [], []]
for i in range(len(train_data['ram'])):
    if(train_data['price_range'][i] == 0):
        ram_lst[0].append(train_data['ram'][i])
        battery_lst[0].append(train_data['battery_power'][i])

    elif(train_data['price_range'][i] == 1):
        ram_lst[1].append(train_data['ram'][i])
        battery_lst[1].append(train_data['battery_power'][i])

    elif(train_data['price_range'][i] == 2):
        ram_lst[2].append(train_data['ram'][i])
        battery_lst[2].append(train_data['battery_power'][i])

    elif(train_data['price_range'][i] == 3):
        ram_lst[3].append(train_data['ram'][i])
        battery_lst[3].append(train_data['battery_power'][i])

boxplot_label = ['1', '2', '3', '4']
plt.boxplot(ram_lst, labels=boxplot_label, patch_artist=True)
plt.title('RAM vs Price boxplot')
plt.xlabel('Price')
plt.ylabel('RAM')
plt.show()

# %%
boxplot_label = ['1', '2', '3', '4']
plt.boxplot(battery_lst, labels=boxplot_label, patch_artist=True)
plt.title('Battery power vs Price boxplot')
plt.xlabel('Price')
plt.ylabel('Battery power')
plt.show()

# %%
p0 = plt.scatter(ram_lst[0], battery_lst[0], c='blue', s=10)
p1 = plt.scatter(ram_lst[1], battery_lst[1], c='red', s=10)
p2 = plt.scatter(ram_lst[2], battery_lst[2], c='green', s=10)
p3 = plt.scatter(ram_lst[3], battery_lst[3], c='magenta', s=10)
plt.xlabel('RAM')
plt.ylabel('Battery power')
plt.legend((p0, p1, p2, p3), ('Price0', 'Price1', 'Price2', 'Price3'), loc='lower left', fontsize=8)
plt.show()

# %%
X = train_data.drop('price_range', axis=1)
X.shape
# Out:
# (2000, 20)

# %%
y = train_data['price_range']
y.shape
# Out:
# (2000,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
print(X_train.shape)
print(X_val.shape)
print(y_train.shape)
print(y_val.shape)
# Out:
# (1600, 20)
# (400, 20)
# (1600,)
# (400,)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

param_grid = { 
    'min_samples_leaf': [i for i in range(1, 11)],
    'min_samples_split': [3, 5, 7, 9],
    'criterion' : ['gini', 'entropy'],
    'max_depth' : [i for i in range(1,11)]
}

dtc = DecisionTreeClassifier(random_state=1)
grid_dtc = GridSearchCV(n_jobs=-1, estimator=dtc, cv=5, param_grid=param_grid)
grid_dtc.fit(X_train,y_train)

print("best score: ", grid_dtc.best_score_)
print("best param: ", grid_dtc.best_params_)
# Out:
# best score:  0.8543749999999999
# best param:  {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 5, 'min_samples_split': 3}

# %%
dtc_model = DecisionTreeClassifier( random_state=1,
                                    min_samples_leaf=grid_dtc.best_params_['min_samples_leaf'],
                                    min_samples_split=grid_dtc.best_params_['min_samples_split'],
                                    criterion=grid_dtc.best_params_['criterion'],
                                    max_depth=grid_dtc.best_params_['max_depth'])

dtc_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=9, min_samples_leaf=5,
#                        min_samples_split=3, random_state=1)

# %%
# accuracy recall precision fscore
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

y_pred = dtc_model.predict(X_val)

dtc_lst = {'name': 'DT',
          'accuracy': accuracy_score(y_val, y_pred), 
          'precision': precision_score(y_val, y_pred, average='macro'),
          'recall': recall_score(y_val, y_pred, average='macro'),
          'F1': f1_score(y_val, y_pred, average='macro')}

print('The "Accruacy" of {0} model is {1:.5f}'.format(dtc_lst['name'], dtc_lst['accuracy']))
print('The "Precision" of {0} model is {1:.5f}'.format(dtc_lst['name'], dtc_lst['precision']))
print('The "Recall" of {0} model is {1:.5f}'.format(dtc_lst['name'], dtc_lst['recall'])) 
print('The "F1" of {0} model is {1:.5f}'.format(dtc_lst['name'], dtc_lst['F1']))
# Out:
# The "Accruacy" of DT model is 0.82750
# The "Precision" of DT model is 0.83110
# The "Recall" of DT model is 0.82782
# The "F1" of DT model is 0.82882

# %%
from sklearn.ensemble import RandomForestClassifier

param_grid = { 
    'n_estimators': [10, 20, 30, 40, 50],
    'max_features': [10, 12, 14, 16, 18, 20],
    'max_depth' : [10, 11, 12, 13, 14, 15],
    'criterion' : ['gini', 'entropy']
}

rfc = RandomForestClassifier(random_state=1)
grid_rfc = GridSearchCV(n_jobs=-1, estimator=rfc, cv=5, param_grid=param_grid)
grid_rfc.fit(X_train,y_train)

print("best score: ", grid_rfc.best_score_)
print("best param: ", grid_rfc.best_params_)
# Out:
# best score:  0.9100000000000001
# best param:  {'criterion': 'entropy', 'max_depth': 12, 'max_features': 14, 'n_estimators': 50}

# %%
# Define the model. Set random_state to 1
rfc_model = RandomForestClassifier( random_state=1,
                                    n_estimators=grid_rfc.best_params_['n_estimators'],
                                    max_features=grid_rfc.best_params_['max_features'],
                                    max_depth=grid_rfc.best_params_['max_depth'],
                                    criterion=grid_rfc.best_params_['criterion'])

rfc_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=12, max_features=14,
#                        n_estimators=50, random_state=1)

# %%
y_pred = rfc_model.predict(X_val)

rfc_lst = {'name': 'RF',
          'accuracy': accuracy_score(y_val, y_pred), 
          'precision': precision_score(y_val, y_pred, average='macro'),
          'recall': recall_score(y_val, y_pred, average='macro'),
          'F1': f1_score(y_val, y_pred, average='macro')}

print('The "Accruacy" of {0} model is {1:.5f}'.format(rfc_lst['name'], rfc_lst['accuracy']))
print('The "Precision" of {0} model is {1:.5f}'.format(rfc_lst['name'], rfc_lst['precision']))
print('The "Recall" of {0} model is {1:.5f}'.format(rfc_lst['name'], rfc_lst['recall'])) 
print('The "F1" of {0} model is {1:.5f}'.format(rfc_lst['name'], rfc_lst['F1']))
# Out:
# The "Accruacy" of RF model is 0.89750
# The "Precision" of RF model is 0.89897
# The "Recall" of RF model is 0.89894
# The "F1" of RF model is 0.89847

# %%
rdc_lst = []
print("{:<25}{:<5}".format("特徵", "重要程度"))
for i in range(len(test_data.columns) - 1):
    print("{:<25}{:<5}".format(test_data.columns[i], round(rfc_model.feature_importances_[i], 8)))
# Out:
# 特徵                       重要程度
# battery_power            0.0959943
# blue                     0.00085516
# clock_speed              0.00619573
# dual_sim                 0.00135371
# fc                       0.00503226
# four_g                   0.00148723
# int_memory               0.00753628
# m_dep                    0.00578161
# mobile_wt                0.01379761
# n_cores                  0.00614841
# pc                       0.00717743
# px_height                0.06167919
# px_width                 0.05896675
# ram                      0.70364728
# sc_h                     0.00560886
# sc_w                     0.00694853
# talk_time                0.00850298
# three_g                  0.00105299
# touch_screen             0.00113

# %%
from sklearn.svm import SVC

param_grid = { 
    'C' : [1, 0.1, 0.25, 0.5, 2, 0.75],
    'kernel' : ["linear", "rbf"],
    'gamma' : ["auto", 0.01, 0.001, 0.0001, 1],
    'decision_function_shape' : ["ovo", "ovr"]
}

svc=SVC(random_state=1)
grid_svc=GridSearchCV(n_jobs=-1, estimator=svc, cv=5, param_grid=param_grid)
grid_svc.fit(X_train,y_train)

print("best score: ", grid_svc.best_score_)
print("best param: ", grid_svc.best_params_)
# Out:
# best score:  0.971875
# best param:  {'C': 0.1, 'decision_function_shape': 'ovo', 'gamma': 'auto', 'kernel': 'linear'}

# %%
# 創建SVC模型
svc_model = SVC( random_state=1,
                 C=grid_svc.best_params_['C'],
                 decision_function_shape=grid_svc.best_params_['decision_function_shape'],
                 gamma=grid_svc.best_params_['gamma'],
                 kernel=grid_svc.best_params_['kernel'])

# 擬合模型（進行訓練）
svc_model.fit(X_train, y_train)
# Out:
# SVC(C=0.1, decision_function_shape='ovo', gamma='auto', kernel='linear',
#     random_state=1)

# %%
y_pred = svc_model.predict(X_val)
svc_lst = {'name': 'SVC',
          'accuracy': accuracy_score(y_val, y_pred), 
          'precision': precision_score(y_val, y_pred, average='macro'),
          'recall': recall_score(y_val, y_pred, average='macro'),
          'F1': f1_score(y_val, y_pred, average='macro')}

print('The "Accruacy" of {0} model is {1:.5f}'.format(svc_lst['name'], svc_lst['accuracy']))
print('The "Precision" of {0} model is {1:.5f}'.format(svc_lst['name'], svc_lst['precision']))
print('The "Recall" of {0} model is {1:.5f}'.format(svc_lst['name'], svc_lst['recall'])) 
print('The "F1" of {0} model is {1:.5f}'.format(svc_lst['name'], svc_lst['F1']))
# Out:
# The "Accruacy" of SVC model is 0.97500
# The "Precision" of SVC model is 0.97509
# The "Recall" of SVC model is 0.97496
# The "F1" of SVC model is 0.97498

# %%
from sklearn.neighbors import KNeighborsClassifier

param_grid = { 
    'n_neighbors' : [i for i in range(1, 21)],
    'weights' : ['uniform', 'distance'],
    'p' : [i for i in range(1,11)],
    
}

knn=KNeighborsClassifier()
grid_knn=GridSearchCV(n_jobs=-1, estimator=knn, cv=5, param_grid=param_grid)
grid_knn.fit(X_train,y_train)

print("best score: ", grid_knn.best_score_)
print("best param: ", grid_knn.best_params_)
# Out:
# best score:  0.9375
# best param:  {'n_neighbors': 12, 'p': 10, 'weights': 'distance'}

# %%
# Define the model. Set random_state to 1
knn_model = KNeighborsClassifier(   n_neighbors=grid_knn.best_params_['n_neighbors'],
                                    weights=grid_knn.best_params_['weights'],
                                    p=grid_knn.best_params_['p']
                                    )

knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=12, p=10, weights='distance')

# %%
y_pred = knn_model.predict(X_val)
knn_lst = {'name': 'KNN',
          'accuracy': accuracy_score(y_val, y_pred), 
          'precision': precision_score(y_val, y_pred, average='macro'),
          'recall': recall_score(y_val, y_pred, average='macro'),
          'F1': f1_score(y_val, y_pred, average='macro')}

print('The "Accruacy" of {0} model is {1:.5f}'.format(knn_lst['name'], knn_lst['accuracy']))
print('The "Precision" of {0} model is {1:.5f}'.format(knn_lst['name'], knn_lst['precision']))
print('The "Recall" of {0} model is {1:.5f}'.format(knn_lst['name'], knn_lst['recall'])) 
print('The "F1" of {0} model is {1:.5f}'.format(knn_lst['name'], knn_lst['F1']))
# Out:
# The "Accruacy" of KNN model is 0.92250
# The "Precision" of KNN model is 0.92478
# The "Recall" of KNN model is 0.92458
# The "F1" of KNN model is 0.92413

# %%
output = pd.DataFrame(  {'accuracy':  {dtc_lst['name']: dtc_lst['accuracy'], 
                                       rfc_lst['name']: rfc_lst['accuracy'],
                                       svc_lst['name']: svc_lst['accuracy'],
                                       knn_lst['name']: knn_lst['accuracy']
                                      },

                        'precision':  {dtc_lst['name']: dtc_lst['precision'], 
                                       rfc_lst['name']: rfc_lst['precision'],
                                       svc_lst['name']: svc_lst['precision'],
                                       knn_lst['name']: knn_lst['precision']
                                      },

                        'recall':     {dtc_lst['name']: dtc_lst['recall'], 
                                       rfc_lst['name']: rfc_lst['recall'],
                                       svc_lst['name']: svc_lst['recall'],
                                       knn_lst['name']: knn_lst['recall']
                                      },

                        'F1':         {dtc_lst['name']: dtc_lst['F1'], 
                                       rfc_lst['name']: rfc_lst['F1'],
                                       svc_lst['name']: svc_lst['F1'],
                                       knn_lst['name']: knn_lst['F1']
                                      }}         
                                    
                      )

output
# Out:
#      accuracy  precision    recall        F1
# DT     0.8275   0.831097  0.827817  0.828816
# RF     0.8975   0.898972  0.898937  0.898472
# SVC    0.9750   0.975090  0.974960  0.974981
# KNN    0.9225   0.924781  0.924582  0.924135

# %%
# Random Forest
feature_importances = []

for i in range(len(test_data.columns) - 1):
    feature_name = test_data.columns[i]
    importance = rfc_model.feature_importances_[i]
    feature_importances.append((feature_name, importance))

# 根據重要性值排序
sorted_feature_importances = sorted(feature_importances, key=lambda x: x[1], reverse=True)

# 輸出結果
print("{:<23}{:<5}".format("特徵", "重要程度"))
print('-'*40)
for feature, importance in sorted_feature_importances:
    print("{:<25}{:<5}".format(feature, round(importance, 8)))
# Out:
# 特徵                     重要程度
# ----------------------------------------
# ram                      0.70364728
# battery_power            0.0959943
# px_height                0.06167919
# px_width                 0.05896675
# mobile_wt                0.01379761
# talk_time                0.00850298
# int_memory               0.00753628
# pc                       0.00717743
# sc_w                     0.00694853
# clock_speed              0.00619573
# n_cores                  0.00614841
# m_dep                    0.00578161
# sc_h                     0.00560886
# fc                       0.00503226
# four_g                   0.00148723
# dual_sim                 0.00135371
# touch_screen             0.00113
# three_g                  0.00105299
# blue                     0.00085516

# %%
# Pandas
df = pd.DataFrame(corr.sort_values(by=["price_range"],ascending=False).iloc[0].sort_values(ascending=False))
df = df[1:]
# df.iloc[0].name
print("{:<23}{:<5}".format("特徵", "重要程度"))
print('-'*40)
for i in range(len(df)):
# for feature, importance in sorted_feature_importances:
    feature = df.iloc[i].name
    importance = df.iloc[i][0]
    print("{:<25}{:<5}".format(feature, round(importance, 8)))
# Out:
# 特徵                     重要程度
# ----------------------------------------
# ram                      0.91704574
# battery_power            0.20072261
# px_width                 0.1658175
# px_height                0.14885756
# int_memory               0.04443496
# sc_w                     0.03871127
# pc                       0.0335993
# three_g                  0.02361122
# sc_h                     0.02298607
# fc                       0.02199821
# talk_time                0.02185887
# blue                     0.02057285
# wifi                     0.01878481
# dual_sim                 0.01744448
# four_g                   0.01477171
# n_cores                  0.00439927
# m_dep                    0.00085304
# clock_speed              -0.00660569
# mobile_wt                -0.03030217
# touch_screen             -0.03041107

# %%
print("{:<5}{:<23}{:<5}".format(' ',"corr()", "Random Forest"))
print('-'*45)
for i in range(10):
    pandas_feature = df.iloc[i].name
    rf_feature = sorted_feature_importances[i][0]
    print("{:<5}{:<23}{:<5}".format(str(i+1)+'.', pandas_feature, rf_feature))
# Out:
#      corr()                 Random Forest
# ---------------------------------------------
# 1.   ram                    ram
# 2.   battery_power          battery_power
# 3.   px_width               px_height
# 4.   px_height              px_width
# 5.   int_memory             mobile_wt
# 6.   sc_w                   talk_time
# 7.   pc                     int_memory
# 8.   three_g                pc
# 9.   sc_h                   sc_w
# 10.  fc                     clock_speed
